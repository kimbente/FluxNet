# %%
import pandas as pd
import numpy as np
import xarray as xr
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, Dataset, DataLoader, random_split
import matplotlib.pyplot as plt
import os

from models import FluxNet
from models import compute_divergence_field

device = "cuda" if torch.cuda.is_available() else "cpu"

RETRAIN = False
# RETRAIN = True

# %% [markdown]
# # Load data

# %%
data = torch.load("data/flux_tensor.pt", weights_only = False)

### Make torch.dataset ###
# takes two separate tensors as input
dataset = TensorDataset(data[:, :2], data[:, 2:])

# Inspect
# Shape of (first) X sample
print(dataset[0][0].shape)
# Shape of (first) Y sample
print(dataset[0][1].shape)

### Create DataLoader ###
all_loader = DataLoader(dataset, batch_size = 1024, shuffle = True)
# Out:
# torch.Size([2])
# torch.Size([2])

# %%
# ----- Training loop -----
if RETRAIN:
    model = FluxNet().to(device)
    # 5e-3 was a bit jittery
    optim = torch.optim.AdamW(model.parameters(), lr = 1e-3, weight_decay = 1e-7)
    loss_function = nn.MSELoss()

    epochs = 12
    # epochs = 10

    losses = []

    for ep in range(1, epochs + 1):
        # ------------------ TRAIN ------------------
        model.train()
        train_loss_sum = 0.0
        
        # NOTE: Train on ALL data (no split)
        for i, (X_batch, Y_batch) in enumerate(all_loader):

            X_batch = X_batch.to(device)
            Y_batch = Y_batch.to(device)

            optim.zero_grad(set_to_none = True)

            Y_hat = model(X_batch)

            loss = loss_function(Y_hat, Y_batch)
            
            loss.backward()
            optim.step()

            train_loss_sum += loss.item() * X_batch.size(0)

        epoch_avg_train_loss = train_loss_sum / len(all_loader.dataset)

        # store for plotting later
        losses.append(epoch_avg_train_loss)

        # Print every epoch: ~ 2 min per epoch
        # ~14 min for 10 epochs on GPU
        print(f"[epoch {ep:03d}] train_loss = {epoch_avg_train_loss:.6f}")

    # ------------------ SAVE ------------------
    torch.save(model.state_dict(), "fluxnet_trained_on_all_data/fluxnet_full_model.pth")
    pd.DataFrame({'train_loss': losses}).to_csv("fluxnet_trained_on_all_data/fluxnet_loss.csv", index = False)
# Out:
# [epoch 001] train_loss = 0.100079
# [epoch 002] train_loss = 0.017520
# [epoch 003] train_loss = 0.014341
# [epoch 004] train_loss = 0.012736
# [epoch 005] train_loss = 0.010777
# [epoch 006] train_loss = 0.010108
# [epoch 007] train_loss = 0.009279
# [epoch 008] train_loss = 0.008930
# [epoch 009] train_loss = 0.008500
# [epoch 010] train_loss = 0.008055
# [epoch 011] train_loss = 0.008243
# [epoch 012] train_loss = 0.007471

# %% [markdown]
# trained in 22 minutes (12 epochs).

# %% [markdown]
# ## Visualise loss convergence

# %%
if RETRAIN:
    # Assume you already have train_losses and test_losses lists
    epochs = range(1, len(losses) + 1)

    plt.figure(figsize = (8, 6))
    plt.plot(epochs, losses, label = "Train Loss", marker = "o", color = "gray")

    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title("Training and Test Loss")
    plt.legend()

    plt.grid(True, linestyle = "--", alpha = 0.2)
    #plt.ylim(0, 0.3)
    plt.show()

# %% [markdown]
# # Load trained model

# %%
# Initialise
model = FluxNet().to(device)
# Load trained weights
model.load_state_dict(torch.load("fluxnet_trained_on_all_data/fluxnet_full_model.pth", map_location = device))
model.eval()
# Out:
# /tmp/ipykernel_286668/2545997332.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("trained_models/fluxnet_full_model.pth", map_location = device))
# FluxNet(
#   (inp): Sequential(
#     (0): Linear(in_features=2, out_features=256, bias=True)
#     (1): SiLU()
#   )
#   (trunk): ModuleList(
#     (0-5): 6 x _ResBlock(
#       (lin1): Linear(in_features=256, out_features=256, bias=True)
#       (lin2): Linear(in_features=256, out_features=256, bias=True)
#       (act): SiLU()
#     )
#   )
#   (head_df_psi): Linear(in_features=256, out_features=1, bias=True)
#   (head_cf_phi): Linear(in_features=256, out_features=1, bias=True)
# )

# %%
# All data is a bit dense (and memory intensive), so we spatially subsample
def spatial_subsample(data, n_cells = 100):
    x, y = data[:, 0], data[:, 1]

    # Compute integer cell indices
    ix = torch.clamp((x * n_cells).long(), max = n_cells - 1)
    iy = torch.clamp((y * n_cells).long(), max = n_cells - 1)
    cell_ids = ix * n_cells + iy   # [N]

    # Shuffle indices to randomize
    perm = torch.randperm(data.shape[0])
    cell_ids_perm = cell_ids[perm]

    # Get inverse mapping: which unique id each entry belongs to
    unique_ids, inv = torch.unique(cell_ids_perm, return_inverse = True)

    # First index per unique id = argmin within each group
    # Build a large index tensor and take the min
    arange = torch.arange(len(cell_ids_perm), device = data.device)
    first_idx = torch.full((len(unique_ids),), len(cell_ids_perm), device = data.device)

    first_idx = first_idx.scatter_reduce(0, inv, arange, reduce = "amin", include_self = True)

    # Map back to permuted indices
    chosen = perm[first_idx]

    return data[chosen]

# 11 k e.g
subset = spatial_subsample(data, n_cells = 200)
print(subset.shape)
# Out:
# torch.Size([11252, 4])

# %%
subset_x = subset[:, :2].to(device)
subset_y = subset[:, 2:].to(device)

prediction = model(subset_x.requires_grad_(True))

div_field = compute_divergence_field(
    mean_pred = prediction, 
    x_grad = subset_x)

rmse_field = torch.sqrt(torch.mean((prediction - subset_y) ** 2, dim = 1))
me_field = torch.mean((prediction - subset_y), dim = 1)
me_field.mean()
# Out:
# tensor(-0.0066, device='cuda:0', grad_fn=<MeanBackward0>)

# %%
plt.figure(figsize = (8, 8))
plt.scatter(
    subset_x[:, 0].cpu().detach().numpy(), 
    subset_x[:, 1].cpu().detach().numpy(),
    c = me_field.cpu().detach().numpy(), 
    cmap = "Reds", 
    vmin = 0, vmax = 1,
    s = 10)
plt.colorbar(label = "Error")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Predicted Error")
plt.ylim(0, 1)
plt.xlim(0, 1)
plt.gca().set_aspect("equal")
plt.show()

# %%
plt.figure(figsize = (8, 8))
plt.scatter(
    subset_x[:, 0].cpu().detach().numpy(), 
    subset_x[:, 1].cpu().detach().numpy(),
    c = div_field.cpu().detach().numpy(), 
    cmap = "RdBu", 
    vmin = -10, vmax = 10,
    s = 10)
plt.colorbar(label = "Error")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Divergence Field")
plt.ylim(0, 1)
plt.xlim(0, 1)
plt.gca().set_aspect("equal")
plt.show()

# %% [markdown]
# # Test points

# %%
from regions import ROSS_BOUNDS

x_min = ROSS_BOUNDS["x_min"]
x_max = ROSS_BOUNDS["x_max"]
y_min = ROSS_BOUNDS["y_min"]
y_max = ROSS_BOUNDS["y_max"]

# %%
target_grid_mask = xr.load_dataset("data/target_grid_mask.nc")

X, Y = xr.broadcast(target_grid_mask.x, target_grid_mask.y)

X_long = X.values.flatten()
Y_long = Y.values.flatten()

# NOTE: Normalise to [0, 1] as model input
X_long = (X_long - x_min) / (x_max - x_min)
Y_long = (Y_long - y_min) / (y_max - y_min)

# mask_long = target_grid_mask.mask.values.flatten()

XY_long_tensor = torch.cat((torch.tensor(X_long).unsqueeze(1), torch.tensor(Y_long).unsqueeze(1)), dim = 1)
print(XY_long_tensor.shape)
print(XY_long_tensor[0:5, :])
# Out:
# torch.Size([4000000, 2])
# tensor([[2.5000e-04, 9.9975e-01],
#         [2.5000e-04, 9.9925e-01],
#         [2.5000e-04, 9.9875e-01],
#         [2.5000e-04, 9.9825e-01],
#         [2.5000e-04, 9.9775e-01]])

# %% [markdown]
# # Inference

# %%
# breaks with 100_000 batch size
batch_size = 10_000

# Move model to device
model = model.to(device)
# Put in eval mode
model.eval()

# Move data to device (not too big for memory)
XY_long_tensor = XY_long_tensor.to(device)

# Total length
N = XY_long_tensor.shape[0]

# container for divergence batches
div_container = torch.empty((N,), dtype = torch.float32, device = "cpu")
 
for i in range(0, N, batch_size):

    # Define end index
    j = min(i + batch_size, N)

    print(f"Processing batch {i} to {j}...")

    # Subset batch
    XY_batch = XY_long_tensor[i : j , :]

    # Enable gradients
    XY_batch = XY_batch.requires_grad_(True)

    flux_predictions_batch = model(XY_batch)

    div_batch = compute_divergence_field(
        mean_pred = flux_predictions_batch, 
        x_grad = XY_batch)
    
    # For now only return divergence
    div_container[i:j] = div_batch.detach().cpu() 

    del div_batch
    del flux_predictions_batch
    torch.cuda.empty_cache()

    # for testing
    # if j == 100_000:
    #    break
# Out:
# Processing batch 0 to 10000...
# Processing batch 10000 to 20000...
# Processing batch 20000 to 30000...
# Processing batch 30000 to 40000...
# Processing batch 40000 to 50000...
# Processing batch 50000 to 60000...
# Processing batch 60000 to 70000...
# Processing batch 70000 to 80000...
# Processing batch 80000 to 90000...
# Processing batch 90000 to 100000...
# Processing batch 100000 to 110000...
# Processing batch 110000 to 120000...
# Processing batch 120000 to 130000...
# Processing batch 130000 to 140000...
# Processing batch 140000 to 150000...
# Processing batch 150000 to 160000...
# Processing batch 160000 to 170000...
# Processing batch 170000 to 180000...
# Processing batch 180000 to 190000...
# Processing batch 190000 to 200000...
# Processing batch 200000 to 210000...
# Processing batch 210000 to 220000...
# Processing batch 220000 to 230000...
# Processing batch 230000 to 240000...
# Processing batch 240000 to 250000...
# Processing batch 250000 to 260000...
# Processing batch 260000 to 270000...
# Processing batch 270000 to 280000...
# Processing batch 280000 to 290000...
# Processing batch 290000 to 300000...
# Processing batch 300000 to 310000...
# Processing batch 310000 to 320000...
# Processing batch 320000 to 330000...
# Processing batch 330000 to 340000...
# Processing batch 340000 to 350000...
# Processing batch 350000 to 360000...
# Processing batch 360000 to 370000...
# Processing batch 370000 to 380000...
# Processing batch 380000 to 390000...
# Processing batch 390000 to 400000...
# Processing batch 400000 to 410000...
# Processing batch 410000 to 420000...
# Processing batch 420000 to 430000...
# Processing batch 430000 to 440000...
# Processing batch 440000 to 450000...
# Processing batch 450000 to 460000...
# Processing batch 460000 to 470000...
# Processing batch 470000 to 480000...
# Processing batch 480000 to 490000...
# Processing batch 490000 to 500000...
# Processing batch 500000 to 510000...
# Processing batch 510000 to 520000...
# Processing batch 520000 to 530000...
# Processing batch 530000 to 540000...
# Processing batch 540000 to 550000...
# Processing batch 550000 to 560000...
# Processing batch 560000 to 570000...
# Processing batch 570000 to 580000...
# Processing batch 580000 to 590000...
# Processing batch 590000 to 600000...
# Processing batch 600000 to 610000...
# Processing batch 610000 to 620000...
# Processing batch 620000 to 630000...
# Processing batch 630000 to 640000...
# Processing batch 640000 to 650000...
# Processing batch 650000 to 660000...
# Processing batch 660000 to 670000...
# Processing batch 670000 to 680000...
# Processing batch 680000 to 690000...
# Processing batch 690000 to 700000...
# Processing batch 700000 to 710000...
# Processing batch 710000 to 720000...
# Processing batch 720000 to 730000...
# Processing batch 730000 to 740000...
# Processing batch 740000 to 750000...
# Processing batch 750000 to 760000...
# Processing batch 760000 to 770000...
# Processing batch 770000 to 780000...
# Processing batch 780000 to 790000...
# Processing batch 790000 to 800000...
# Processing batch 800000 to 810000...
# Processing batch 810000 to 820000...
# Processing batch 820000 to 830000...
# Processing batch 830000 to 840000...
# Processing batch 840000 to 850000...
# Processing batch 850000 to 860000...
# Processing batch 860000 to 870000...
# Processing batch 870000 to 880000...
# Processing batch 880000 to 890000...
# Processing batch 890000 to 900000...
# Processing batch 900000 to 910000...
# Processing batch 910000 to 920000...
# Processing batch 920000 to 930000...
# Processing batch 930000 to 940000...
# Processing batch 940000 to 950000...
# Processing batch 950000 to 960000...
# Processing batch 960000 to 970000...
# Processing batch 970000 to 980000...
# Processing batch 980000 to 990000...
# Processing batch 990000 to 1000000...
# Processing batch 1000000 to 1010000...
# Processing batch 1010000 to 1020000...
# Processing batch 1020000 to 1030000...
# Processing batch 1030000 to 1040000...
# Processing batch 1040000 to 1050000...
# Processing batch 1050000 to 1060000...
# Processing batch 1060000 to 1070000...
# Processing batch 1070000 to 1080000...
# Processing batch 1080000 to 1090000...
# Processing batch 1090000 to 1100000...
# Processing batch 1100000 to 1110000...
# Processing batch 1110000 to 1120000...
# Processing batch 1120000 to 1130000...
# Processing batch 1130000 to 1140000...
# Processing batch 1140000 to 1150000...
# Processing batch 1150000 to 1160000...
# Processing batch 1160000 to 1170000...
# Processing batch 1170000 to 1180000...
# Processing batch 1180000 to 1190000...
# Processing batch 1190000 to 1200000...
# Processing batch 1200000 to 1210000...
# Processing batch 1210000 to 1220000...
# Processing batch 1220000 to 1230000...
# Processing batch 1230000 to 1240000...
# Processing batch 1240000 to 1250000...
# Processing batch 1250000 to 1260000...
# Processing batch 1260000 to 1270000...
# Processing batch 1270000 to 1280000...
# Processing batch 1280000 to 1290000...
# Processing batch 1290000 to 1300000...
# Processing batch 1300000 to 1310000...
# Processing batch 1310000 to 1320000...
# Processing batch 1320000 to 1330000...
# Processing batch 1330000 to 1340000...
# Processing batch 1340000 to 1350000...
# Processing batch 1350000 to 1360000...
# Processing batch 1360000 to 1370000...
# Processing batch 1370000 to 1380000...
# Processing batch 1380000 to 1390000...
# Processing batch 1390000 to 1400000...
# Processing batch 1400000 to 1410000...
# Processing batch 1410000 to 1420000...
# Processing batch 1420000 to 1430000...
# Processing batch 1430000 to 1440000...
# Processing batch 1440000 to 1450000...
# Processing batch 1450000 to 1460000...
# Processing batch 1460000 to 1470000...
# Processing batch 1470000 to 1480000...
# Processing batch 1480000 to 1490000...
# Processing batch 1490000 to 1500000...
# Processing batch 1500000 to 1510000...
# Processing batch 1510000 to 1520000...
# Processing batch 1520000 to 1530000...
# Processing batch 1530000 to 1540000...
# Processing batch 1540000 to 1550000...
# Processing batch 1550000 to 1560000...
# Processing batch 1560000 to 1570000...
# Processing batch 1570000 to 1580000...
# Processing batch 1580000 to 1590000...
# Processing batch 1590000 to 1600000...
# Processing batch 1600000 to 1610000...
# Processing batch 1610000 to 1620000...
# Processing batch 1620000 to 1630000...
# Processing batch 1630000 to 1640000...
# Processing batch 1640000 to 1650000...
# Processing batch 1650000 to 1660000...
# Processing batch 1660000 to 1670000...
# Processing batch 1670000 to 1680000...
# Processing batch 1680000 to 1690000...
# Processing batch 1690000 to 1700000...
# Processing batch 1700000 to 1710000...
# Processing batch 1710000 to 1720000...
# Processing batch 1720000 to 1730000...
# Processing batch 1730000 to 1740000...
# Processing batch 1740000 to 1750000...
# Processing batch 1750000 to 1760000...
# Processing batch 1760000 to 1770000...
# Processing batch 1770000 to 1780000...
# Processing batch 1780000 to 1790000...
# Processing batch 1790000 to 1800000...
# Processing batch 1800000 to 1810000...
# Processing batch 1810000 to 1820000...
# Processing batch 1820000 to 1830000...
# Processing batch 1830000 to 1840000...
# Processing batch 1840000 to 1850000...
# Processing batch 1850000 to 1860000...
# Processing batch 1860000 to 1870000...
# Processing batch 1870000 to 1880000...
# Processing batch 1880000 to 1890000...
# Processing batch 1890000 to 1900000...
# Processing batch 1900000 to 1910000...
# Processing batch 1910000 to 1920000...
# Processing batch 1920000 to 1930000...
# Processing batch 1930000 to 1940000...
# Processing batch 1940000 to 1950000...
# Processing batch 1950000 to 1960000...
# Processing batch 1960000 to 1970000...
# Processing batch 1970000 to 1980000...
# Processing batch 1980000 to 1990000...
# Processing batch 1990000 to 2000000...
# Processing batch 2000000 to 2010000...
# Processing batch 2010000 to 2020000...
# Processing batch 2020000 to 2030000...
# Processing batch 2030000 to 2040000...
# Processing batch 2040000 to 2050000...
# Processing batch 2050000 to 2060000...
# Processing batch 2060000 to 2070000...
# Processing batch 2070000 to 2080000...
# Processing batch 2080000 to 2090000...
# Processing batch 2090000 to 2100000...
# Processing batch 2100000 to 2110000...
# Processing batch 2110000 to 2120000...
# Processing batch 2120000 to 2130000...
# Processing batch 2130000 to 2140000...
# Processing batch 2140000 to 2150000...
# Processing batch 2150000 to 2160000...
# Processing batch 2160000 to 2170000...
# Processing batch 2170000 to 2180000...
# Processing batch 2180000 to 2190000...
# Processing batch 2190000 to 2200000...
# Processing batch 2200000 to 2210000...
# Processing batch 2210000 to 2220000...
# Processing batch 2220000 to 2230000...
# Processing batch 2230000 to 2240000...
# Processing batch 2240000 to 2250000...
# Processing batch 2250000 to 2260000...
# Processing batch 2260000 to 2270000...
# Processing batch 2270000 to 2280000...
# Processing batch 2280000 to 2290000...
# Processing batch 2290000 to 2300000...
# Processing batch 2300000 to 2310000...
# Processing batch 2310000 to 2320000...
# Processing batch 2320000 to 2330000...
# Processing batch 2330000 to 2340000...
# Processing batch 2340000 to 2350000...
# Processing batch 2350000 to 2360000...
# Processing batch 2360000 to 2370000...
# Processing batch 2370000 to 2380000...
# Processing batch 2380000 to 2390000...
# Processing batch 2390000 to 2400000...
# Processing batch 2400000 to 2410000...
# Processing batch 2410000 to 2420000...
# Processing batch 2420000 to 2430000...
# Processing batch 2430000 to 2440000...
# Processing batch 2440000 to 2450000...
# Processing batch 2450000 to 2460000...
# Processing batch 2460000 to 2470000...
# Processing batch 2470000 to 2480000...
# Processing batch 2480000 to 2490000...
# Processing batch 2490000 to 2500000...
# Processing batch 2500000 to 2510000...
# Processing batch 2510000 to 2520000...
# Processing batch 2520000 to 2530000...
# Processing batch 2530000 to 2540000...
# Processing batch 2540000 to 2550000...
# Processing batch 2550000 to 2560000...
# Processing batch 2560000 to 2570000...
# Processing batch 2570000 to 2580000...
# Processing batch 2580000 to 2590000...
# Processing batch 2590000 to 2600000...
# Processing batch 2600000 to 2610000...
# Processing batch 2610000 to 2620000...
# Processing batch 2620000 to 2630000...
# Processing batch 2630000 to 2640000...
# Processing batch 2640000 to 2650000...
# Processing batch 2650000 to 2660000...
# Processing batch 2660000 to 2670000...
# Processing batch 2670000 to 2680000...
# Processing batch 2680000 to 2690000...
# Processing batch 2690000 to 2700000...
# Processing batch 2700000 to 2710000...
# Processing batch 2710000 to 2720000...
# Processing batch 2720000 to 2730000...
# Processing batch 2730000 to 2740000...
# Processing batch 2740000 to 2750000...
# Processing batch 2750000 to 2760000...
# Processing batch 2760000 to 2770000...
# Processing batch 2770000 to 2780000...
# Processing batch 2780000 to 2790000...
# Processing batch 2790000 to 2800000...
# Processing batch 2800000 to 2810000...
# Processing batch 2810000 to 2820000...
# Processing batch 2820000 to 2830000...
# Processing batch 2830000 to 2840000...
# Processing batch 2840000 to 2850000...
# Processing batch 2850000 to 2860000...
# Processing batch 2860000 to 2870000...
# Processing batch 2870000 to 2880000...
# Processing batch 2880000 to 2890000...
# Processing batch 2890000 to 2900000...
# Processing batch 2900000 to 2910000...
# Processing batch 2910000 to 2920000...
# Processing batch 2920000 to 2930000...
# Processing batch 2930000 to 2940000...
# Processing batch 2940000 to 2950000...
# Processing batch 2950000 to 2960000...
# Processing batch 2960000 to 2970000...
# Processing batch 2970000 to 2980000...
# Processing batch 2980000 to 2990000...
# Processing batch 2990000 to 3000000...
# Processing batch 3000000 to 3010000...
# Processing batch 3010000 to 3020000...
# Processing batch 3020000 to 3030000...
# Processing batch 3030000 to 3040000...
# Processing batch 3040000 to 3050000...
# Processing batch 3050000 to 3060000...
# Processing batch 3060000 to 3070000...
# Processing batch 3070000 to 3080000...
# Processing batch 3080000 to 3090000...
# Processing batch 3090000 to 3100000...
# Processing batch 3100000 to 3110000...
# Processing batch 3110000 to 3120000...
# Processing batch 3120000 to 3130000...
# Processing batch 3130000 to 3140000...
# Processing batch 3140000 to 3150000...
# Processing batch 3150000 to 3160000...
# Processing batch 3160000 to 3170000...
# Processing batch 3170000 to 3180000...
# Processing batch 3180000 to 3190000...
# Processing batch 3190000 to 3200000...
# Processing batch 3200000 to 3210000...
# Processing batch 3210000 to 3220000...
# Processing batch 3220000 to 3230000...
# Processing batch 3230000 to 3240000...
# Processing batch 3240000 to 3250000...
# Processing batch 3250000 to 3260000...
# Processing batch 3260000 to 3270000...
# Processing batch 3270000 to 3280000...
# Processing batch 3280000 to 3290000...
# Processing batch 3290000 to 3300000...
# Processing batch 3300000 to 3310000...
# Processing batch 3310000 to 3320000...
# Processing batch 3320000 to 3330000...
# Processing batch 3330000 to 3340000...
# Processing batch 3340000 to 3350000...
# Processing batch 3350000 to 3360000...
# Processing batch 3360000 to 3370000...
# Processing batch 3370000 to 3380000...
# Processing batch 3380000 to 3390000...
# Processing batch 3390000 to 3400000...
# Processing batch 3400000 to 3410000...
# Processing batch 3410000 to 3420000...
# Processing batch 3420000 to 3430000...
# Processing batch 3430000 to 3440000...
# Processing batch 3440000 to 3450000...
# Processing batch 3450000 to 3460000...
# Processing batch 3460000 to 3470000...
# Processing batch 3470000 to 3480000...
# Processing batch 3480000 to 3490000...
# Processing batch 3490000 to 3500000...
# Processing batch 3500000 to 3510000...
# Processing batch 3510000 to 3520000...
# Processing batch 3520000 to 3530000...
# Processing batch 3530000 to 3540000...
# Processing batch 3540000 to 3550000...
# Processing batch 3550000 to 3560000...
# Processing batch 3560000 to 3570000...
# Processing batch 3570000 to 3580000...
# Processing batch 3580000 to 3590000...
# Processing batch 3590000 to 3600000...
# Processing batch 3600000 to 3610000...
# Processing batch 3610000 to 3620000...
# Processing batch 3620000 to 3630000...
# Processing batch 3630000 to 3640000...
# Processing batch 3640000 to 3650000...
# Processing batch 3650000 to 3660000...
# Processing batch 3660000 to 3670000...
# Processing batch 3670000 to 3680000...
# Processing batch 3680000 to 3690000...
# Processing batch 3690000 to 3700000...
# Processing batch 3700000 to 3710000...
# Processing batch 3710000 to 3720000...
# Processing batch 3720000 to 3730000...
# Processing batch 3730000 to 3740000...
# Processing batch 3740000 to 3750000...
# Processing batch 3750000 to 3760000...
# Processing batch 3760000 to 3770000...
# Processing batch 3770000 to 3780000...
# Processing batch 3780000 to 3790000...
# Processing batch 3790000 to 3800000...
# Processing batch 3800000 to 3810000...
# Processing batch 3810000 to 3820000...
# Processing batch 3820000 to 3830000...
# Processing batch 3830000 to 3840000...
# Processing batch 3840000 to 3850000...
# Processing batch 3850000 to 3860000...
# Processing batch 3860000 to 3870000...
# Processing batch 3870000 to 3880000...
# Processing batch 3880000 to 3890000...
# Processing batch 3890000 to 3900000...
# Processing batch 3900000 to 3910000...
# Processing batch 3910000 to 3920000...
# Processing batch 3920000 to 3930000...
# Processing batch 3930000 to 3940000...
# Processing batch 3940000 to 3950000...
# Processing batch 3950000 to 3960000...
# Processing batch 3960000 to 3970000...
# Processing batch 3970000 to 3980000...
# Processing batch 3980000 to 3990000...
# Processing batch 3990000 to 4000000...

# %% [markdown]
# # Reshape long input

# %%
# make square
div_container_square = div_container.unsqueeze(1).reshape(target_grid_mask.x.shape[0], target_grid_mask.x.shape[0])

# mask out the values outside of the boundry
# NOTE: Need to transpose mask to match dimensions
mask = torch.as_tensor(target_grid_mask["mask"].values.T, device = div_container_square.device)
div_square = div_container_square.masked_fill(mask != 1, float("nan"))

# %%
plt.figure(figsize = (8, 8))
plt.pcolormesh(
    # NOTE: 2D inputs
    # NOTE: Take original coords
    torch.tensor(X.values).cpu().detach().numpy(), 
    torch.tensor(Y.values).cpu().detach().numpy(),
    div_square.cpu().detach().numpy(), 
    cmap = "RdBu", 
    # equivalent to a -3, 3 mapping
    vmax = 30, 
    vmin = -30)
plt.colorbar(label = "Error")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Divergence Field")
plt.gca().set_aspect("equal")
plt.show()

# %% [markdown]
# # Convert units back to physical units
#
# - **dxy = 1_000_000** because the normalised range [0, 1] presents [0, 1_000_000 m] (1000 km range) in real life.
# - **flux_scale = 100_000** because we devided fluxes by 100_000 to acheve ~ 1 std i.e. var of flux in both directions.
#     - The mean ice thickness of 420 meters * 438 mean ice speed yields ice flux of 183_960 for example.
# - To rescale the div_field to physical units we do **div_phys = div_field * flux_scale / dxy**
# - This simplifies to **dividing by 10** to get **m / year** units.

# %% [markdown]
# # Visualise with MODIS

# %%
vis_again = True

# Only rerun if needed
if vis_again :

    # Load MODIS data
    modis_ross = torch.load("data/modis/moa125_2014_hp1_v01_ross_with_grid_no_ocean.pt", weights_only = False)

    fig, ax = plt.subplots(figsize = (8, 6))

    # 1) MODIS as background (draw first)
    ax.pcolormesh(
        modis_ross[0],
        modis_ross[1], 
        modis_ross[2],
        cmap = "gray",
        # softer greys
        vmin = -30_000, 
        vmax = 30_000,
        # as less saturated background
        alpha = 0.4,
        zorder = 0,
    )

    # 2) SMB on top (draw second)
    pcm = ax.pcolormesh(
        # NOTE: 2D inputs
        # NOTE: Take original coords
        torch.tensor(X.values).cpu().detach().numpy(), 
        torch.tensor(Y.values).cpu().detach().numpy(),
        div_square.cpu().detach().numpy(), 
        vmin = -30,
        vmax = 30,
        cmap = "RdBu",
        shading = "auto",
        alpha = 1.0,
        zorder = 1,
    )

    ax.set_aspect("equal")
    ax.set_axis_off()

    fig.savefig("figures/fluxnet_div_ross.png", dpi = 300, bbox_inches = "tight", pad_inches = 0)
    plt.show()

# %% [markdown]
# # Generate file / overwrite variable in existing file

# %%
path = "data/fluxnet_div_ross.nc"

# make field numpy and scale
# m i.e. / yr
div_np = div_square.cpu().detach().numpy() / 10.0 

# ensure (y,x) ordering on the target grid
div_da = xr.DataArray(
    div_np,
    dims = ("y", "x"),
    coords = {"x": target_grid_mask["x"], "y": target_grid_mask["y"]},
    name = "fluxnet_div",
    attrs = {
        "long_name": "Flux divergence (net) converted to metres ice-equivalent per year",
        "units": "m i.e. yr-1",
    },
).transpose("y", "x")  # no-op if already correct

if not os.path.exists(path):
    ds = div_da.to_dataset()
else:
    with xr.open_dataset(path) as _ds:
        ds = _ds.load()
    ds = ds.assign_coords(x = target_grid_mask["x"], y = target_grid_mask["y"])

ds["fluxnet_div"] = div_da

tmp = path + ".tmp"
ds.to_netcdf(tmp, mode = "w")
os.replace(tmp, path)
